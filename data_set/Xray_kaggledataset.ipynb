# %% [markdown]
# <a href="https://colab.research.google.com/github/suryanshyadav2023-tech/AI_X_Ray_Project/blob/main/data_set/Xray_kaggledataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install the Kaggle API client
! pip install -q kaggle

# 2. Upload the kaggle.json file from your computer
from google.colab import files
files.upload() # A prompt will appear to select your file
# Out:
#      <input type="file" id="files-9c7b013c-c346-4e5c-8a2f-f85b1d462a49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c7b013c-c346-4e5c-8a2f-f85b1d462a49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !head /content/data/sample/sample_labels.csv
# Out:
# Image Index,Finding Labels,Follow-up #,Patient ID,Patient Age,Patient Gender,View Position,OriginalImageWidth,OriginalImageHeight,OriginalImagePixelSpacing_x,OriginalImagePixelSpacing_y
# 00000013_005.png,Emphysema|Infiltration|Pleural_Thickening|Pneumothorax,005,00000013,060Y,M,AP,3056,2544,0.139,0.139
# 00000013_026.png,Cardiomegaly|Emphysema,026,00000013,057Y,M,AP,2500,2048,0.168,0.168
# 00000017_001.png,No Finding,001,00000017,077Y,M,AP,2500,2048,0.168,0.168
# 00000030_001.png,Atelectasis,001,00000030,079Y,M,PA,2992,2991,0.143,0.143
# 00000032_001.png,Cardiomegaly|Edema|Effusion,001,00000032,055Y,F,AP,2500,2048,0.168,0.168
# 00000040_003.png,Consolidation|Mass,003,00000040,068Y,M,PA,2500,2048,0.168,0.168
# 00000042_002.png,No Finding,002,00000042,071Y,M,AP,3056,2544,0.139,0.139
# 00000057_001.png,No Finding,001,00000057,071Y,M,AP,3056,2544,0.139,0.139
# 00000061_002.png,Effusion,002,00000061,077Y,M,PA,2992,2991,0.143,0.143

# %%
# !ls data/sample/images/
# Out:
# 00000013_005.png  00007298_002.png  00013996_005.png  00020671_000.png
# 00000013_026.png  00007302_000.png  00013999_001.png  00020671_001.png
# 00000017_001.png  00007304_002.png  00013999_005.png  00020673_041.png
# 00000030_001.png  00007316_000.png  00014004_001.png  00020673_048.png
# 00000032_001.png  00007322_012.png  00014004_012.png  00020679_000.png
# 00000040_003.png  00007322_015.png  00014004_013.png  00020680_000.png
# 00000042_002.png  00007322_016.png  00014004_045.png  00020680_005.png
# 00000057_001.png  00007322_019.png  00014006_010.png  00020683_000.png
# 00000061_002.png  00007322_021.png  00014010_006.png  00020691_000.png
# 00000061_019.png  00007322_030.png  00014015_001.png  00020703_000.png
# 00000061_025.png  00007328_012.png  00014018_015.png  00020703_009.png
# 00000079_000.png  00007330_001.png  00014018_016.png  00020705_000.png
# 00000080_005.png  00007335_000.png  00014022_070.png  00020725_001.png
# ...

# %%
# !rm kaggle\ \(1\).json

# %%
# Download the sample dataset and unzip it directly into the content folder
! kaggle datasets download -d nih-chest-xrays/sample -p /content/data --unzip

# Define paths for the rest of your notebook:
DATA_DIR = '/content/data/sample/images/'
CSV_PATH = '/content/data/sample/sample_labels.csv'

print("Kaggle data setup complete. Proceed to multi-label encoding.")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nih-chest-xrays/sample
# License(s): CC0-1.0
# ...
#  99% 4.17G/4.20G [01:18<00:00, 46.5MB/s]
# 100% 4.20G/4.20G [01:21<00:00, 55.4MB/s]
# Kaggle data setup complete. Proceed to multi-label encoding.
